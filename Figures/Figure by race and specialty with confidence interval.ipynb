# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.stats.proportion import proportion_confint

# %%
df = pd.read_csv("~/Telehealth/Data/telehealth_final_video_230101.csv")

# %%
df = df[df["encounter_status_name"]!= "Canceled"]

# %%
df["encounter_status_name"].value_counts()

# %%
df = df[df["race_ethnic_cat3"]!= "Other"]
df["race_ethnic_cat3"].value_counts()

# %%
def my_recode(is_telehealth):
    if is_telehealth == True:
        return "Telehealth"
    else:
        return "In-person"

# %%
df['is_telehealth'] = df['is_telehealth'].apply(my_recode)
df["is_telehealth"].value_counts()

# %%
def my_recode(month_quarter):
    if month_quarter == "Jan to Mar 2019":
        return "2019 0103"
    elif month_quarter == "Jan to Mar 2020":
        return "2020 0103"
    elif month_quarter == "Jan to Mar 2021":
        return "2021 0103"
    elif month_quarter == "Jan to Mar 2022":
        return "2022 0103"
    elif month_quarter == "Apr to Jun 2019":
        return "2019 0406"
    elif month_quarter == "Apr to Jun 2020":
        return "2020 0406"
    elif month_quarter == "Apr to Jun 2021":
        return "2021 0406"
    elif month_quarter == "Apr to Jun 2022":
        return "2022 0406"
    elif month_quarter == "Jul to Sep 2019":
        return "2019 0709"
    elif month_quarter == "Jul to Sep 2020":
        return "2020 0709"
    elif month_quarter == "Jul to Sep 2021":
        return "2021 0709"
    elif month_quarter == "Jul to Sep 2022":
        return "2022 0709"
    elif month_quarter == "Oct to Dec 2019":
        return "2019 1012"
    elif month_quarter == "Oct to Dec 2020":
        return "2020 1012"
    elif month_quarter == "Oct to Dec 2021":
        return "2021 1012"
    elif month_quarter == "Oct to Dec 2022":
        return "2022 1012"
    else:
        return

# %%
df['month_quarter'] = df['month_quarter'].apply(my_recode)
df["month_quarter"].value_counts()

# %%
df_c = df[df["encounter_status_name"]=="Completed"]
df_ns = df[df["encounter_status_name"]=="No Show"]
df_cancel = df[df["encounter_status_name"]=="Canceled"]

# %%
df_Mental = df[df["provider_specialty_cat"]=="Mental Health and Behavioral Health"]
df_Endocrinology = df[df["provider_specialty_cat"]=="Endocrinology"]
df_Genetics = df[df["provider_specialty_cat"]=="Genetics"]

df_telehealth = df[df["is_telehealth"]=="Telehealth"]
df_Mental_telehealth = df_telehealth[df_telehealth["provider_specialty_cat"]=="Mental Health and Behavioral Health"]
df_Endocrinology_telehealth = df_telehealth[df_telehealth["provider_specialty_cat"]=="Endocrinology"]
df_Genetics_telehealth = df_telehealth[df_telehealth["provider_specialty_cat"]=="Genetics"]

df_inperson = df[df["is_telehealth"]=="In-person"]
df_Mental_inperson = df_inperson[df_inperson["provider_specialty_cat"]=="Mental Health and Behavioral Health"]
df_Endocrinology_inperson = df_inperson[df_inperson["provider_specialty_cat"]=="Endocrinology"]
df_Genetics_inperson = df_inperson[df_inperson["provider_specialty_cat"]=="Genetics"]

# %%
df["encounter_status_name"].value_counts()

# %%
df["month_quarter"]

# %%
#both telehealth and inperson
#ALL
data_crosstab = pd.crosstab([df["month_quarter"], df["race_ethnic_cat3"]], 
                             df["encounter_status_name"], margins = False)
total = pd.crosstab([df["month_quarter"], df["race_ethnic_cat3"]], 
                             df["encounter_status_name"]).apply(lambda row: round(row.sum(),1), axis=1).reset_index()
percentages = pd.crosstab([df["month_quarter"], df["race_ethnic_cat3"]], 
                             df["encounter_status_name"]).apply(lambda row: round(row/row.sum()*100,1), axis=1).reset_index()

summaryTable_all=pd.merge(data_crosstab,total,on=["month_quarter","race_ethnic_cat3"])
summaryTable_all=pd.merge(summaryTable_all,percentages,on=["month_quarter","race_ethnic_cat3"])

summaryTable_all["95confint"] = summaryTable_all.apply(lambda x: proportion_confint(x["No Show_x"], x[0], alpha=0.05, method='normal')
                                               ,axis=1)
summaryTable_all['95confint'] = summaryTable_all['95confint'].astype(str)
summaryTable_all['lower_ci'] = summaryTable_all['95confint'].str.split(',').str[0]
summaryTable_all['lower_ci'] = summaryTable_all['lower_ci'].str.replace("(", "")
summaryTable_all['lower_ci'] = summaryTable_all.apply(lambda x: float(x['lower_ci'][0:6])*100,axis=1)

summaryTable_all['upper_ci'] = summaryTable_all['95confint'].str.split(',').str[1]
summaryTable_all['upper_ci'] = summaryTable_all['upper_ci'].str.replace(")", "")
summaryTable_all['upper_ci'] = summaryTable_all.apply(lambda x: float(x['upper_ci'][0:6])*100,axis=1)

#mental health 
#both telehealth and inperson
#ALL
data_crosstab = pd.crosstab([df_Mental["month_quarter"], df_Mental["race_ethnic_cat3"]], 
                             df_Mental["encounter_status_name"], margins = False)
total = pd.crosstab([df_Mental["month_quarter"], df_Mental["race_ethnic_cat3"]], 
                             df_Mental["encounter_status_name"]).apply(lambda row: round(row.sum(),1), axis=1).reset_index()
percentages = pd.crosstab([df_Mental["month_quarter"], df_Mental["race_ethnic_cat3"]], 
                             df_Mental["encounter_status_name"]).apply(lambda row: round(row/row.sum()*100,1), axis=1).reset_index()

summaryTable_Mental=pd.merge(data_crosstab,total,on=["month_quarter","race_ethnic_cat3"])
summaryTable_Mental=pd.merge(summaryTable_Mental,percentages,on=["month_quarter","race_ethnic_cat3"])

summaryTable_Mental["95confint"] = summaryTable_Mental.apply(lambda x: proportion_confint(x["No Show_x"], x[0], alpha=0.05, method='normal')
                                               ,axis=1)
summaryTable_Mental['95confint'] = summaryTable_Mental['95confint'].astype(str)
summaryTable_Mental['lower_ci'] = summaryTable_Mental['95confint'].str.split(',').str[0]
summaryTable_Mental['lower_ci'] = summaryTable_Mental['lower_ci'].str.replace("(", "")
summaryTable_Mental['lower_ci'] = summaryTable_Mental.apply(lambda x: float(x['lower_ci'][0:6])*100,axis=1)

summaryTable_Mental['upper_ci'] = summaryTable_Mental['95confint'].str.split(',').str[1]
summaryTable_Mental['upper_ci'] = summaryTable_Mental['upper_ci'].str.replace(")", "")
summaryTable_Mental['upper_ci'] = summaryTable_Mental.apply(lambda x: float(x['upper_ci'][0:6])*100,axis=1)

# %%
#telehealth

#ALL
data_crosstab = pd.crosstab([df_telehealth["month_quarter"], df_telehealth["race_ethnic_cat3"]], 
                             df_telehealth["encounter_status_name"], margins = False)
total = pd.crosstab([df_telehealth["month_quarter"], df_telehealth["race_ethnic_cat3"]], 
                             df_telehealth["encounter_status_name"]).apply(lambda row: round(row.sum(),1), axis=1).reset_index()
percentages = pd.crosstab([df_telehealth["month_quarter"], df["race_ethnic_cat3"]], 
                             df_telehealth["encounter_status_name"]).apply(lambda row: round(row/row.sum()*100,1), axis=1).reset_index()

summaryTable_telehealth=pd.merge(data_crosstab,total,on=["month_quarter","race_ethnic_cat3"])
summaryTable_telehealth=pd.merge(summaryTable_telehealth,percentages,on=["month_quarter","race_ethnic_cat3"])

summaryTable_telehealth["95confint"] = summaryTable_telehealth.apply(lambda x: proportion_confint(x["No Show_x"], x[0], alpha=0.05, method='normal')
                                               ,axis=1)
summaryTable_telehealth['95confint'] = summaryTable_telehealth['95confint'].astype(str)
summaryTable_telehealth['lower_ci'] = summaryTable_telehealth['95confint'].str.split(',').str[0]
summaryTable_telehealth['lower_ci'] = summaryTable_telehealth['lower_ci'].str.replace("(", "")
summaryTable_telehealth['lower_ci'] = summaryTable_telehealth.apply(lambda x: float(x['lower_ci'][0:6])*100,axis=1)

summaryTable_telehealth['upper_ci'] = summaryTable_telehealth['95confint'].str.split(',').str[1]
summaryTable_telehealth['upper_ci'] = summaryTable_telehealth['upper_ci'].str.replace(")", "")
summaryTable_telehealth['upper_ci'] = summaryTable_telehealth.apply(lambda x: float(x['upper_ci'][0:6])*100,axis=1)

#mental health 
#both telehealth and inperson
#ALL
data_crosstab = pd.crosstab([df_Mental_telehealth["month_quarter"], df_Mental_telehealth["race_ethnic_cat3"]], 
                             df_Mental_telehealth["encounter_status_name"], margins = False)
total = pd.crosstab([df_Mental_telehealth["month_quarter"], df_Mental_telehealth["race_ethnic_cat3"]], 
                             df_Mental_telehealth["encounter_status_name"]).apply(lambda row: round(row.sum(),1), axis=1).reset_index()
percentages = pd.crosstab([df_Mental_telehealth["month_quarter"], df_Mental_telehealth["race_ethnic_cat3"]], 
                             df_Mental_telehealth["encounter_status_name"]).apply(lambda row: round(row/row.sum()*100,1), axis=1).reset_index()

summaryTable_Mental_telehealth=pd.merge(data_crosstab,total,on=["month_quarter","race_ethnic_cat3"])
summaryTable_Mental_telehealth=pd.merge(summaryTable_Mental_telehealth,percentages,on=["month_quarter","race_ethnic_cat3"])

summaryTable_Mental_telehealth["95confint"] = summaryTable_Mental_telehealth.apply(lambda x: proportion_confint(x["No Show_x"], x[0], alpha=0.05, method='normal')
                                               ,axis=1)
summaryTable_Mental_telehealth['95confint'] = summaryTable_Mental_telehealth['95confint'].astype(str)
summaryTable_Mental_telehealth['lower_ci'] = summaryTable_Mental_telehealth['95confint'].str.split(',').str[0]
summaryTable_Mental_telehealth['lower_ci'] = summaryTable_Mental_telehealth['lower_ci'].str.replace("(", "")
summaryTable_Mental_telehealth['lower_ci'] = summaryTable_Mental_telehealth.apply(lambda x: float(x['lower_ci'][0:6])*100,axis=1)

summaryTable_Mental_telehealth['upper_ci'] = summaryTable_Mental_telehealth['95confint'].str.split(',').str[1]
summaryTable_Mental_telehealth['upper_ci'] = summaryTable_Mental_telehealth['upper_ci'].str.replace(")", "")
summaryTable_Mental_telehealth['upper_ci'] = summaryTable_Mental_telehealth.apply(lambda x: float(x['upper_ci'][0:6])*100,axis=1)

# %%
#inperson

#ALL
data_crosstab = pd.crosstab([df_inperson["month_quarter"], df_inperson["race_ethnic_cat3"]], 
                             df_inperson["encounter_status_name"], margins = False)
total = pd.crosstab([df_inperson["month_quarter"], df_inperson["race_ethnic_cat3"]], 
                             df_inperson["encounter_status_name"]).apply(lambda row: round(row.sum(),1), axis=1).reset_index()
percentages = pd.crosstab([df_inperson["month_quarter"], df_inperson["race_ethnic_cat3"]], 
                             df_inperson["encounter_status_name"]).apply(lambda row: round(row/row.sum()*100,1), axis=1).reset_index()

summaryTable_inperson=pd.merge(data_crosstab,total,on=["month_quarter","race_ethnic_cat3"])
summaryTable_inperson=pd.merge(summaryTable_inperson,percentages,on=["month_quarter","race_ethnic_cat3"])

summaryTable_inperson["95confint"] = summaryTable_inperson.apply(lambda x: proportion_confint(x["No Show_x"], x[0], alpha=0.05, method='normal')
                                               ,axis=1)
summaryTable_inperson['95confint'] = summaryTable_inperson['95confint'].astype(str)
summaryTable_inperson['lower_ci'] = summaryTable_inperson['95confint'].str.split(',').str[0]
summaryTable_inperson['lower_ci'] = summaryTable_inperson['lower_ci'].str.replace("(", "")
summaryTable_inperson['lower_ci'] = summaryTable_inperson.apply(lambda x: float(x['lower_ci'][0:6])*100,axis=1)

summaryTable_inperson['upper_ci'] = summaryTable_inperson['95confint'].str.split(',').str[1]
summaryTable_inperson['upper_ci'] = summaryTable_inperson['upper_ci'].str.replace(")", "")
summaryTable_inperson['upper_ci'] = summaryTable_inperson.apply(lambda x: float(x['upper_ci'][0:6])*100,axis=1)

#mental health
data_crosstab = pd.crosstab([df_Mental_inperson["month_quarter"], df_Mental_inperson["race_ethnic_cat3"]], 
                             df_Mental_inperson["encounter_status_name"], margins = False)
total = pd.crosstab([df_Mental_inperson["month_quarter"], df_Mental_inperson["race_ethnic_cat3"]], 
                             df_Mental_inperson["encounter_status_name"]).apply(lambda row: round(row.sum(),1), axis=1).reset_index()
percentages = pd.crosstab([df_Mental_inperson["month_quarter"], df_Mental_inperson["race_ethnic_cat3"]], 
                             df_Mental_inperson["encounter_status_name"]).apply(lambda row: round(row/row.sum()*100,1), axis=1).reset_index()

summaryTable_Mental_inperson=pd.merge(data_crosstab,total,on=["month_quarter","race_ethnic_cat3"])
summaryTable_Mental_inperson=pd.merge(summaryTable_Mental_inperson,percentages,on=["month_quarter","race_ethnic_cat3"])

summaryTable_Mental_inperson["95confint"] = summaryTable_Mental_inperson.apply(lambda x: proportion_confint(x["No Show_x"], x[0], alpha=0.05, method='normal')
                                               ,axis=1)
summaryTable_Mental_inperson['95confint'] = summaryTable_Mental_inperson['95confint'].astype(str)
summaryTable_Mental_inperson['lower_ci'] = summaryTable_Mental_inperson['95confint'].str.split(',').str[0]
summaryTable_Mental_inperson['lower_ci'] = summaryTable_Mental_inperson['lower_ci'].str.replace("(", "")
summaryTable_Mental_inperson['lower_ci'] = summaryTable_Mental_inperson.apply(lambda x: float(x['lower_ci'][0:6])*100,axis=1)

summaryTable_Mental_inperson['upper_ci'] = summaryTable_Mental_inperson['95confint'].str.split(',').str[1]
summaryTable_Mental_inperson['upper_ci'] = summaryTable_Mental_inperson['upper_ci'].str.replace(")", "")
summaryTable_Mental_inperson['upper_ci'] = summaryTable_Mental_inperson.apply(lambda x: float(x['upper_ci'][0:6])*100,axis=1)

# %%
#ALL
summaryTable_black_all = summaryTable_all[summaryTable_all["race_ethnic_cat3"]=="Non-Hispanic Black"]
summaryTable_white_all = summaryTable_all[summaryTable_all["race_ethnic_cat3"]=="Non-Hispanic White"]
summaryTable_hispanic_all = summaryTable_all[summaryTable_all["race_ethnic_cat3"]=="Hispanic"]
summaryTable_other_all = summaryTable_all[summaryTable_all["race_ethnic_cat3"]=="Other"]

summaryTable_black_telehealth = summaryTable_telehealth[summaryTable_telehealth["race_ethnic_cat3"]=="Non-Hispanic Black"]
summaryTable_white_telehealth = summaryTable_telehealth[summaryTable_telehealth["race_ethnic_cat3"]=="Non-Hispanic White"]
summaryTable_hispanic_telehealth = summaryTable_telehealth[summaryTable_telehealth["race_ethnic_cat3"]=="Hispanic"]
summaryTable_other_telehealth = summaryTable_telehealth[summaryTable_telehealth["race_ethnic_cat3"]=="Other"]

summaryTable_black_inperson = summaryTable_inperson[summaryTable_inperson["race_ethnic_cat3"]=="Non-Hispanic Black"]
summaryTable_white_inperson = summaryTable_inperson[summaryTable_inperson["race_ethnic_cat3"]=="Non-Hispanic White"]
summaryTable_hispanic_inperson = summaryTable_inperson[summaryTable_inperson["race_ethnic_cat3"]=="Hispanic"]
summaryTable_other_inperson = summaryTable_inperson[summaryTable_inperson["race_ethnic_cat3"]=="Other"]

#Mental health 
summaryTable_black_Mental = summaryTable_Mental[summaryTable_Mental["race_ethnic_cat3"]=="Non-Hispanic Black"]
summaryTable_white_Mental = summaryTable_Mental[summaryTable_Mental["race_ethnic_cat3"]=="Non-Hispanic White"]
summaryTable_hispanic_Mental = summaryTable_Mental[summaryTable_Mental["race_ethnic_cat3"]=="Hispanic"]
summaryTable_other_Mental = summaryTable_Mental[summaryTable_Mental["race_ethnic_cat3"]=="Other"]

summaryTable_black_Mental_telehealth = summaryTable_Mental_telehealth[summaryTable_Mental_telehealth["race_ethnic_cat3"]=="Non-Hispanic Black"]
summaryTable_white_Mental_telehealth = summaryTable_Mental_telehealth[summaryTable_Mental_telehealth["race_ethnic_cat3"]=="Non-Hispanic White"]
summaryTable_hispanic_Mental_telehealth = summaryTable_Mental_telehealth[summaryTable_Mental_telehealth["race_ethnic_cat3"]=="Hispanic"]
summaryTable_other_Mental_telehealth = summaryTable_Mental_telehealth[summaryTable_Mental_telehealth["race_ethnic_cat3"]=="Other"]

summaryTable_black_Mental_inperson = summaryTable_Mental_inperson[summaryTable_Mental_inperson["race_ethnic_cat3"]=="Non-Hispanic Black"]
summaryTable_white_Mental_inperson = summaryTable_Mental_inperson[summaryTable_Mental_inperson["race_ethnic_cat3"]=="Non-Hispanic White"]
summaryTable_hispanic_Mental_inperson = summaryTable_Mental_inperson[summaryTable_Mental_inperson["race_ethnic_cat3"]=="Hispanic"]
summaryTable_other_Mental_inperson = summaryTable_Mental_inperson[summaryTable_Mental_inperson["race_ethnic_cat3"]=="Other"]

# %%
summaryTable_black_all

# %%
summaryTable_hispanic_telehealth

# %%
summaryTable_hispanic_inperson

# %%
summaryTable_white_telehealth

# %%
summaryTable_hispanic_telehealth

# %%
# Creating plot with dataset_1
fig, ((ax1, ax2, ax3),
     (ax4,ax5,ax6)) = plt.subplots(2, 3)

#No Show ALL ----------------------------------------------------------------------------------------
ax1.set_xlabel('Time')
ax1.set_ylabel('Proportion of no-show encounters (%)')
lns1_1 = ax1.plot("month_quarter","No Show_y", 
         data=summaryTable_black_all, 
         color = 'tab:olive',
         label="Non-Hispanic Black"
        )
lns1_2 = ax1.plot("month_quarter",
         "No Show_y", 
         data=summaryTable_white_all, 
         color = 'm',
         label="Non-Hispanic White")
lns1_3 = ax1.plot("month_quarter",
         "No Show_y", 
         data=summaryTable_hispanic_all, 
         color = 'tab:green',
         label="Hispanic")
lns1_4 = ax1.plot("month_quarter",
         "No Show_y", 
         data=summaryTable_other_all, 
         color = 'tab:blue',
         label="Other")
ax1.tick_params(axis ='y')

ax1.fill_between(
    summaryTable_black_all['month_quarter'], 
    summaryTable_black_all['lower_ci'], 
    summaryTable_black_all['upper_ci'], 
    color='y',alpha=0.2)

ax1.fill_between(
    summaryTable_white_all['month_quarter'], 
    summaryTable_white_all['lower_ci'], 
    summaryTable_white_all['upper_ci'], 
    color='pink',alpha=0.2)

ax1.fill_between(
    summaryTable_hispanic_all['month_quarter'], 
    summaryTable_hispanic_all['lower_ci'], 
    summaryTable_hispanic_all['upper_ci'], 
    color='g',alpha=0.2)

ax1.set_title("No-Show Encounters (Telehealth and In-person)")
ax1.set_ylim(-5, 20)

# added these three lines
lns = lns1_1+lns1_2+lns1_3
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=0)
# Names of the xticks albels
time_names = ["Jan 2019","Apr 2019","Jul 2019","Oct 2019",
    "Jan 2020","Apr 2020","Jul 2020","Oct 2020",
    "Jan 2021","Apr 2021","Jul 2021","Oct 2021",
             "Jan 2022","Apr 2022",]
ax1.set_xticklabels(time_names, rotation=90) 

#No Show telehealth ----------------------------------------------------------------------------------------
ax2.set_xlabel('Time')
ax2.set_ylabel('Proportion of no-show encounters (%)')
lns2_1 = ax2.plot("month_quarter","No Show_y", 
         data=summaryTable_black_telehealth, 
         color = 'tab:olive',
         label="Non-Hispanic Black"
        )
lns2_2 = ax2.plot("month_quarter",
         "No Show_y", 
         data=summaryTable_white_telehealth, 
         color = 'm',
         label="Non-Hispanic White")
lns2_3 = ax2.plot("month_quarter",
         "No Show_y", 
         data=summaryTable_hispanic_telehealth, 
         color = 'tab:green',
         label="Hispanic")
lns2_4 = ax2.plot("month_quarter",
         "No Show_y", 
         data=summaryTable_other_telehealth, 
         color = 'tab:blue',
         label="Other")
ax2.tick_params(axis ='y')

ax2.fill_between(
    summaryTable_black_telehealth['month_quarter'], 
    summaryTable_black_telehealth['lower_ci'], 
    summaryTable_black_telehealth['upper_ci'], 
    color='y',alpha=0.2)

ax2.fill_between(
    summaryTable_white_telehealth['month_quarter'], 
    summaryTable_white_telehealth['lower_ci'], 
    summaryTable_white_telehealth['upper_ci'], 
    color='pink',alpha=0.2)

ax2.fill_between(
    summaryTable_hispanic_telehealth['month_quarter'], 
    summaryTable_hispanic_telehealth['lower_ci'], 
    summaryTable_hispanic_telehealth['upper_ci'], 
    color='g',alpha=0.2)

ax2.set_title("No-Show Encounters (Telehealth)")
ax2.set_ylim(-5, 20)

# added these three lines
lns = lns2_1+lns2_2+lns2_3
labs = [l.get_label() for l in lns]
ax2.legend(lns, labs, loc=0)
# Names of the xticks albels
time_names = ["Jan 2019","Apr 2019","Jul 2019","Oct 2019",
    "Jan 2020","Apr 2020","Jul 2020","Oct 2020",
    "Jan 2021","Apr 2021","Jul 2021","Oct 2021",
             "Jan 2022","Apr 2022",]
ax2.set_xticklabels(time_names, rotation=90) 

#No Show in-person ----------------------------------------------------------------------------------------
ax3.set_xlabel('Time')
ax3.set_ylabel('Proportion of no-show encounters (%)')
lns3_1 = ax3.plot("month_quarter","No Show_y", 
         data=summaryTable_black_inperson, 
         color = 'tab:olive',
         label="Non-Hispanic Black"
        )
lns3_2 = ax3.plot("month_quarter",
         "No Show_y", 
         data=summaryTable_white_inperson, 
         color = 'm',
         label="Non-Hispanic White")
lns3_3 = ax3.plot("month_quarter",
         "No Show_y", 
         data=summaryTable_hispanic_inperson, 
         color = 'tab:green',
         label="Hispanic")
lns3_4 = ax3.plot("month_quarter",
         "No Show_y", 
         data=summaryTable_other_inperson, 
         color = 'tab:blue',
         label="Other")
ax3.tick_params(axis ='y')

ax3.fill_between(
    summaryTable_black_inperson['month_quarter'], 
    summaryTable_black_inperson['lower_ci'], 
    summaryTable_black_inperson['upper_ci'], 
    color='y',alpha=0.2)

ax3.fill_between(
    summaryTable_white_inperson['month_quarter'], 
    summaryTable_white_inperson['lower_ci'], 
    summaryTable_white_inperson['upper_ci'], 
    color='pink',alpha=0.2)

ax3.fill_between(
    summaryTable_hispanic_inperson['month_quarter'], 
    summaryTable_hispanic_inperson['lower_ci'], 
    summaryTable_hispanic_inperson['upper_ci'], 
    color='g',alpha=0.2)


ax3.set_title("No-Show Encounters (In-person)")
ax3.set_ylim(-5, 20)

# added these three lines
lns = lns3_1+lns3_2+lns3_3
labs = [l.get_label() for l in lns]
ax3.legend(lns, labs, loc=0)
# Names of the xticks albels
time_names = ["Jan 2019","Apr 2019","Jul 2019","Oct 2019",
    "Jan 2020","Apr 2020","Jul 2020","Oct 2020",
    "Jan 2021","Apr 2021","Jul 2021","Oct 2021",
             "Jan 2022","Apr 2022",]
ax3.set_xticklabels(time_names, rotation=90) 

#No Show MENTAL HEALTH ALL ----------------------------------------------------------------------------------------
ax4.set_xlabel('Time')
ax4.set_ylabel('Proportion of no-show encounters (%)')
lns4_1 = ax4.plot("month_quarter","No Show_y", 
         data=summaryTable_black_Mental, 
         color = 'tab:olive',
         label="Non-Hispanic Black"
        )
lns4_2 = ax4.plot("month_quarter",
         "No Show_y", 
         data=summaryTable_white_Mental, 
         color = 'm',
         label="Non-Hispanic White")
lns4_3 = ax4.plot("month_quarter",
         "No Show_y", 
         data=summaryTable_hispanic_Mental, 
         color = 'tab:green',
         label="Hispanic")
lns4_4 = ax4.plot("month_quarter",
         "No Show_y", 
         data=summaryTable_other_Mental, 
         color = 'tab:blue',
         label="Other")
ax4.tick_params(axis ='y')

ax4.fill_between(
    summaryTable_black_Mental['month_quarter'], 
    summaryTable_black_Mental['lower_ci'], 
    summaryTable_black_Mental['upper_ci'], 
    color='y',alpha=0.2)

ax4.fill_between(
    summaryTable_white_Mental['month_quarter'], 
    summaryTable_white_Mental['lower_ci'], 
    summaryTable_white_Mental['upper_ci'], 
    color='pink',alpha=0.2)

ax4.fill_between(
    summaryTable_hispanic_Mental['month_quarter'], 
    summaryTable_hispanic_Mental['lower_ci'], 
    summaryTable_hispanic_Mental['upper_ci'], 
    color='g',alpha=0.2)

ax4.set_title("No-Show Encounters (Telehealth and In-person)")
ax4.set_ylim(-5, 30)

# added these three lines
lns = lns4_1+lns4_2+lns4_3
labs = [l.get_label() for l in lns]
ax4.legend(lns, labs, loc=0)
# Names of the xticks albels
time_names = ["Jan 2019","Apr 2019","Jul 2019","Oct 2019",
    "Jan 2020","Apr 2020","Jul 2020","Oct 2020",
    "Jan 2021","Apr 2021","Jul 2021","Oct 2021",
             "Jan 2022","Apr 2022",]
ax4.set_xticklabels(time_names, rotation=90) 

#No Show MENTAL HEALTH telehealth ----------------------------------------------------------------------------------------
ax5.set_xlabel('Time')
ax5.set_ylabel('Proportion of no-show encounters (%)')
lns5_1 = ax5.plot("month_quarter","No Show_y", 
         data=summaryTable_black_Mental_telehealth, 
         color = 'tab:olive',
         label="Non-Hispanic Black"
        )
lns5_2 = ax5.plot("month_quarter",
         "No Show_y", 
         data=summaryTable_white_Mental_telehealth, 
         color = 'm',
         label="Non-Hispanic White")
lns5_3 = ax5.plot("month_quarter",
         "No Show_y", 
         data=summaryTable_hispanic_Mental_telehealth, 
         color = 'tab:green',
         label="Hispanic")
lns5_4 = ax5.plot("month_quarter",
         "No Show_y", 
         data=summaryTable_other_Mental_telehealth, 
         color = 'tab:blue',
         label="Other")
ax5.tick_params(axis ='y')

ax5.fill_between(
    summaryTable_black_Mental_telehealth['month_quarter'], 
    summaryTable_black_Mental_telehealth['lower_ci'], 
    summaryTable_black_Mental_telehealth['upper_ci'], 
    color='y',alpha=0.2)

ax5.fill_between(
    summaryTable_white_Mental_telehealth['month_quarter'], 
    summaryTable_white_Mental_telehealth['lower_ci'], 
    summaryTable_white_Mental_telehealth['upper_ci'], 
    color='pink',alpha=0.2)

ax5.fill_between(
    summaryTable_hispanic_Mental_telehealth['month_quarter'], 
    summaryTable_hispanic_Mental_telehealth['lower_ci'], 
    summaryTable_hispanic_Mental_telehealth['upper_ci'], 
    color='g',alpha=0.2)

ax5.set_title("No-Show encounters, Mental Health (Telehealth)")
ax5.set_ylim(-5, 30)

# added these three lines
lns = lns5_1+lns5_2+lns5_3
labs = [l.get_label() for l in lns]
ax5.legend(lns, labs, loc=0)
# Names of the xticks albels
time_names = ["Jan 2019","Apr 2019","Jul 2019","Oct 2019",
    "Jan 2020","Apr 2020","Jul 2020","Oct 2020",
    "Jan 2021","Apr 2021","Jul 2021","Oct 2021",
             "Jan 2022","Apr 2022",]
ax5.set_xticklabels(time_names, rotation=90) 

#No Show MENTAL HEALTH in-person ----------------------------------------------------------------------------------------
ax6.set_xlabel('Time')
ax6.set_ylabel('Proportion of no-show encounters (%)')
lns6_1 = ax6.plot("month_quarter","No Show_y", 
         data=summaryTable_black_Mental_inperson, 
         color = 'tab:olive',
         label="Non-Hispanic Black"
        )
lns6_2 = ax6.plot("month_quarter",
         "No Show_y", 
         data=summaryTable_white_Mental_inperson, 
         color = 'm',
         label="Non-Hispanic White")
lns6_3 = ax6.plot("month_quarter",
         "No Show_y", 
         data=summaryTable_hispanic_Mental_inperson, 
         color = 'tab:green',
         label="Hispanic")
lns6_4 = ax6.plot("month_quarter",
         "No Show_y", 
         data=summaryTable_other_Mental_inperson, 
         color = 'tab:blue',
         label="Other")
ax6.tick_params(axis ='y')

ax6.fill_between(
    summaryTable_black_Mental_inperson['month_quarter'], 
    summaryTable_black_Mental_inperson['lower_ci'], 
    summaryTable_black_Mental_inperson['upper_ci'], 
    color='y',alpha=0.2)

ax6.fill_between(
    summaryTable_white_Mental_inperson['month_quarter'], 
    summaryTable_white_Mental_inperson['lower_ci'], 
    summaryTable_white_Mental_inperson['upper_ci'], 
    color='pink',alpha=0.2)

ax6.fill_between(
    summaryTable_hispanic_Mental_inperson['month_quarter'], 
    summaryTable_hispanic_Mental_inperson['lower_ci'], 
    summaryTable_hispanic_Mental_inperson['upper_ci'], 
    color='g',alpha=0.2)


ax6.set_title("No-Show Encounters, Mental Health (In-person)")
ax6.set_ylim(-5, 30)

# added these three lines
lns = lns6_1+lns6_2+lns6_3
labs = [l.get_label() for l in lns]
ax6.legend(lns, labs, loc=0)
# Names of the xticks albels
time_names = ["Jan 2019","Apr 2019","Jul 2019","Oct 2019",
    "Jan 2020","Apr 2020","Jul 2020","Oct 2020",
    "Jan 2021","Apr 2021","Jul 2021","Oct 2021",
             "Jan 2022","Apr 2022",]
ax6.set_xticklabels(time_names, rotation=90)
fig.set_size_inches(16, 11)
fig.tight_layout(pad=3)

# %%
fig.savefig("race.svg", format="svg")
